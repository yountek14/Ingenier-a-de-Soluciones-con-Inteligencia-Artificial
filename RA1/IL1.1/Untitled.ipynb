# %%
pip install azure-ai-inference
# Out:
# Collecting azure-ai-inference
#   Downloading azure_ai_inference-1.0.0b9-py3-none-any.whl.metadata (34 kB)
# Collecting isodate>=0.6.1 (from azure-ai-inference)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting azure-core>=1.30.0 (from azure-ai-inference)
#   Downloading azure_core-1.39.0-py3-none-any.whl.metadata (48 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in C:\Users\benji\Ingenier-a-de-Soluciones-con-Inteligencia-Artificial\.venv\Lib\site-packages (from azure-ai-inference) (4.15.0)
# Requirement already satisfied: requests>=2.21.0 in C:\Users\benji\Ingenier-a-de-Soluciones-con-Inteligencia-Artificial\.venv\Lib\site-packages (from azure-core>=1.30.0->azure-ai-inference) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\benji\Ingenier-a-de-Soluciones-con-Inteligencia-Artificial\.venv\Lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\benji\Ingenier-a-de-Soluciones-con-Inteligencia-Artificial\.venv\Lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\benji\Ingenier-a-de-Soluciones-con-Inteligencia-Artificial\.venv\Lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\benji\Ingenier-a-de-Soluciones-con-Inteligencia-Artificial\.venv\Lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (2026.2.25)
# Downloading azure_ai_inference-1.0.0b9-py3-none-any.whl (124 kB)
# Downloading azure_core-1.39.0-py3-none-any.whl (218 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Installing collected packages: isodate, azure-core, azure-ai-inference
#
#    ---------------------------------------- 0/3 [isodate]
#    ------------- -------------------------- 1/3 [azure-core]
#    ------------- -------------------------- 1/3 [azure-core]
#    ------------- -------------------------- 1/3 [azure-core]
#    ------------- -------------------------- 1/3 [azure-core]
#    ------------- -------------------------- 1/3 [azure-core]
#    ------------- -------------------------- 1/3 [azure-core]
#    ------------- -------------------------- 1/3 [azure-core]
#    ------------- -------------------------- 1/3 [azure-core]
#    ------------- -------------------------- 1/3 [azure-core]
#    ------------- -------------------------- 1/3 [azure-core]
#    ------------- -------------------------- 1/3 [azure-core]
#    ------------- -------------------------- 1/3 [azure-core]
#    -------------------------- ------------- 2/3 [azure-ai-inference]
#    -------------------------- ------------- 2/3 [azure-ai-inference]
#    -------------------------- ------------- 2/3 [azure-ai-inference]
#    -------------------------- ------------- 2/3 [azure-ai-inference]
#    -------------------------- ------------- 2/3 [azure-ai-inference]
#    -------------------------- ------------- 2/3 [azure-ai-inference]
#    ---------------------------------------- 3/3 [azure-ai-inference]
#
# Successfully installed azure-ai-inference-1.0.0b9 azure-core-1.39.0 isodate-0.7.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

# Cargar variables de entorno desde .env
load_dotenv()

endpoint = "https://models.github.ai/inference"
model = "deepseek/DeepSeek-V3-0324"
# Reemplaza la línea 8 con esto:
token = os.getenv("GITHUB_TOKEN")

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

response = client.complete(
    messages=[
        SystemMessage("You are a helpful assistant."),
        UserMessage("hola"),
    ],
    temperature=1.0,
    top_p=1.0,
    max_tokens=1000,
    model=model
)

print(response.choices[0].message.content)
# Out:
# ¡Hola! 😊 ¿En qué puedo ayudarte hoy?
