# %% [markdown]
# # 3. LangChain Streaming - Respuestas en Tiempo Real
#
# ## Objetivos de Aprendizaje
# - Comprender qué es el streaming y cuándo usarlo
# - Implementar streaming con LangChain
# - Manejar chunks de datos en tiempo real
# - Construir interfaces de usuario reactivas
#
# ## ¿Qué es el Streaming?
#
# El streaming permite recibir la respuesta del modelo **token por token** conforme se genera, en lugar de esperar a que termine completamente. Esto mejora significativamente la experiencia de usuario en aplicaciones interactivas.
#
# ### Ventajas del Streaming:
# - **Percepción de velocidad**: El usuario ve progreso inmediato
# - **Mejor UX**: Interfaces más reactivas e interactivas
# - **Engagement**: Mantiene la atención del usuario
# - **Debugging**: Permite ver el proceso de generación
#
# ### Casos de Uso Ideales:
# - Chatbots y asistentes conversacionales
# - Generación de contenido largo
# - Aplicaciones web interactivas
# - Demostraciones en vivo

# %%
# Importar bibliotecas necesarias
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
import os
import time

print("Bibliotecas importadas correctamente para streaming")
# Out:
# Bibliotecas importadas correctamente para streaming

# %%
# Configuración del modelo con streaming habilitado
try:
    llm = ChatOpenAI(
        base_url=os.getenv("GITHUB_API_URL", "https://models.github.ai/inference"),
        api_key=os.getenv("GITHUB_TOKEN"),
        model="gpt-4.1",
        streaming=True,  # ¡Importante: habilitar streaming!
        temperature=0.7
    )
    
    print("✓ Modelo configurado con streaming habilitado")
    print(f"Modelo: {llm.model_name}")
    print(f"Streaming: {llm.streaming}")
    
except Exception as e:
    print(f"✗ Error en configuración: {e}")
    print("Verifica las variables de entorno")
# Out:
# ✓ Modelo configurado con streaming habilitado
# Modelo: gpt-4.1
# Streaming: True

# %% [markdown]
# ## Streaming Básico
#
# El método `.stream()` devuelve un generador que produce chunks de texto conforme se generan.

# %%
# Ejemplo básico de streaming
def streaming_basico():
    prompt = "Cuéntame una historia corta sobre un programador que descubre la magia en el código"
    
    print("=== STREAMING EN TIEMPO REAL ===")
    print("Generando respuesta...")
    print("-" * 50)
    
    try:
        # stream() devuelve un generador de chunks
        for chunk in llm.stream([HumanMessage(content=prompt)]):
            # Imprimir cada chunk sin nueva línea
            print(chunk.content, end="", flush=True)
            time.sleep(0.01)  # Pequeña pausa para simular streaming visual
            
        print("\n" + "-" * 50)
        print("✓ Streaming completado")
        
    except Exception as e:
        print(f"✗ Error en streaming: {e}")

# Ejecutar streaming básico
streaming_basico()
# Out:
# === STREAMING EN TIEMPO REAL ===
# Generando respuesta...
# --------------------------------------------------
# Había una vez un programador llamado Mateo, que trabajaba incansablemente en una pequeña empresa de tecnología. Cada día, escribía líneas de código y resolvía errores, pero sentía que algo faltaba: su trabajo era eficiente, pero no inspirador.
#
# Una noche, mientras depuraba un programa, Mateo notó algo extraño. Había una función que, al ejecutarla, mostraba un mensaje en la pantalla: "¿Crees en la magia?" Intrigado, revisó el código y vio una línea que nunca había escrito: `if (belief == true) { wish.grant(); }`. Pensó que era una broma de algún compañero, pero al cambiar la variable `belief` a `true`, algo inesperado sucedió: el programa comenzó a dibujar figuras coloridas, a reproducir melodías suaves y a responderle con frases que parecían venir de otro mundo.
#
# Mateo pasó la noche interactuando con el programa. Cada vez que escribía algo con imaginación, el código respondía de manera creativa, como si tuviera vida propia. Entendió que la magia no estaba en trucos o hechizos, sino en la capacidad de crear mundos y posibilidades a través del código. Desde ese día, Mateo escribió sus programas con pasión, buscando sorprender y emocionar a quienes los usaban.
#
# Y así, descubrió que la verdadera magia estaba en el arte de programar, donde cada línea podía ser un portal hacia lo imposible.
# --------------------------------------------------
# ✓ Streaming completado

# %% [markdown]
# ## Comparación: Streaming vs No-Streaming
#
# Veamos la diferencia en experiencia de usuario entre ambos enfoques.

# %%
# Comparación entre streaming y no-streaming
def comparar_streaming():
    # Modelo sin streaming
    llm_no_stream = ChatOpenAI(
        base_url=("https://models.inference.ai.azure.com"),
        api_key=(os.getenv("GITHUB_TOKEN")),  # Reemplaza con tu token
        model="gpt-4o",
        streaming=False,  # Sin streaming
        temperature=0.7
    )
    
    prompt = "Escribe un párrafo sobre las ventajas de la programación en Python"
    
    print("=== COMPARACIÓN: STREAMING vs NO-STREAMING ===\\n")
    
    # 1. Sin streaming
    print("1. SIN STREAMING:")
    print("-" * 20)
    print("Esperando respuesta completa...")
    
    start_time = time.time()
    try:
        response = llm_no_stream.invoke([HumanMessage(content=prompt)])
        end_time = time.time()
        
        print(f"\\n[Respuesta recibida después de {end_time - start_time:.2f} segundos]")
        print(response.content)
        
    except Exception as e:
        print(f"Error: {e}")
    
    print("\\n" + "="*60 + "\\n")
    
    # 2. Con streaming
    print("2. CON STREAMING:")
    print("-" * 18)
    print("Respuesta en tiempo real:")
    
    start_time = time.time()
    try:
        for chunk in llm.stream([HumanMessage(content=prompt)]):
            print(chunk.content, end="", flush=True)
            time.sleep(0.03)  # Simular pausa para efecto visual
        
        end_time = time.time()
        print(f"\\n\\n[Streaming completado en {end_time - start_time:.2f} segundos]")
        
    except Exception as e:
        print(f"Error: {e}")
    
    print("\\n" + "="*60)
    print("OBSERVACIONES:")
    print("- Sin streaming: El usuario espera sin feedback")
    print("- Con streaming: El usuario ve progreso inmediato")
    print("- Mejor percepción de velocidad con streaming")
    print("- Streaming es especial para respuestas largas")

# Ejecutar comparación
comparar_streaming()
# Out:
# === COMPARACIÓN: STREAMING vs NO-STREAMING ===\n
# 1. SIN STREAMING:
# --------------------
# Esperando respuesta completa...
# \n[Respuesta recibida después de 2.92 segundos]
# Python es uno de los lenguajes de programación más populares y versátiles debido a sus numerosas ventajas. Su sintaxis simple y legible facilita el aprendizaje, incluso para principiantes, y permite desarrollar proyectos de manera más rápida y eficiente. Además, Python cuenta con una extensa biblioteca estándar y una enorme comunidad global que respalda su desarrollo, proporcionando módulos y herramientas para casi cualquier necesidad, desde análisis de datos y aprendizaje automático hasta desarrollo web y automatización. Es un lenguaje multiplataforma, lo que significa que el mismo código puede ejecutarse en diferentes sistemas operativos con mínimas modificaciones. Asimismo, su naturaleza de código abierto y su compatibilidad con otros lenguajes de programación lo convierten en una opción flexible y accesible tanto para proyectos pequeños como para aplicaciones empresariales a gran escala.
# \n============================================================\n
# 2. CON STREAMING:
# ------------------
# Respuesta en tiempo real:
# La programación en Python ofrece numerosas ventajas que la han convertido en uno de los lenguajes más populares y utilizados en el mundo. Entre sus principales beneficios destaca su sintaxis sencilla y clara, lo que facilita el aprendizaje tanto para principiantes como para expertos. Además, Python cuenta con una amplia comunidad y una gran cantidad de bibliotecas y frameworks, lo que permite desarrollar aplicaciones en diversos campos como la inteligencia artificial, análisis de datos, desarrollo web y automatización de tareas. Su portabilidad y compatibilidad multiplataforma también hacen que sea una opción flexible y eficiente para proyectos de cualquier tamaño. En resumen, Python proporciona un entorno accesible, potente y versátil para la programación moderna.\n\n[Streaming completado en 5.82 segundos]
# \n============================================================
# OBSERVACIONES:
# - Sin streaming: El usuario espera sin feedback
# - Con streaming: El usuario ve progreso inmediato
# - Mejor percepción de velocidad con streaming
# - Streaming es especial para respuestas largas

# %% [markdown]
# ## Implementación de un Chatbot Simple con Streaming
#
# Creemos un chatbot básico que demuestre el streaming en un contexto práctico.

# %%
# Chatbot simple con streaming
def chatbot_streaming():
    print("=== CHATBOT CON STREAMING ===")
    print("Escribe 'salir' para terminar la conversación\\n")
    
    # Configurar asistente con personalidad
    system_message = """Eres un asistente útil y amigable especializado en tecnología. 
    Respondes de manera clara y concisa, y siempre intentas ser educativo."""
    
    while True:
        # Obtener input del usuario
        user_input = input("\\n🧑 Tú: ")
        
        if user_input.lower() in ['salir', 'exit', 'quit']:
            print("\\n👋 ¡Hasta luego!")
            break
            
        if not user_input.strip():
            continue
            
        print("\\n🤖 Asistente: ", end="", flush=True)
        
        try:
            # Streaming de la respuesta
            messages = [
                {"role": "system", "content": system_message},
                {"role": "user", "content": user_input}
            ]
            
            # Convertir a formato LangChain
            from langchain_core.messages import SystemMessage
            lc_messages = [
                SystemMessage(content=system_message),
                HumanMessage(content=user_input)
            ]
            
            full_response = ""
            for chunk in llm.stream(lc_messages):
                content = chunk.content
                print(content, end="", flush=True)
                full_response += content
                time.sleep(0.02)
                
            print()  # Nueva línea al final
            
        except KeyboardInterrupt:
            print("\\n\\n⏸️ Interrumpido por el usuario")
            break
        except Exception as e:
            print(f"\\n❌ Error: {e}")
            
    print("\\n¡Gracias por usar el chatbot!")

# Ejecutar chatbot (¡Pruébalo!)
chatbot_streaming()  # Descomentar para ejecutar en terminal

print("💡 Descomenta la línea anterior para probar el chatbot interactivo")
# Out:
# === CHATBOT CON STREAMING ===
# Escribe 'salir' para terminar la conversación\n
# \n🧑 Tú:  hola
# \n🤖 Asistente: ¡Hola! ¿En qué puedo ayudarte hoy?
# \n🧑 Tú:  cuanto es 6+6
# \n🤖 Asistente: 6 + 6 es igual a 12.

# %% [markdown]
# ## Streaming Avanzado con Manejo de Chunks
#
# Podemos procesar cada chunk individualmente para crear experiencias más sofisticadas.

# %%
# Streaming con análisis de chunks
def streaming_avanzado():
    prompt = "Explica qué es la inteligencia artificial y cómo funciona el machine learning"
    
    print("=== STREAMING AVANZADO CON ANÁLISIS ===")
    print("Analizando chunks conforme llegan...\n")
    
    # Variables para estadísticas
    chunk_count = 0
    total_content = ""
    words_processed = 0
    
    try:
        for chunk in llm.stream([HumanMessage(content=prompt)]):
            chunk_count += 1
            content = chunk.content
            total_content += content
            
            # Contar palabras aproximadas
            if content.strip():
                words_in_chunk = len(content.split())
                words_processed += words_in_chunk
            
            # Mostrar progreso cada 10 chunks
            if chunk_count % 10 == 0:
                print(f"\\n[Progreso: {chunk_count} chunks, ~{words_processed} palabras]\\n")
            
            # Imprimir el contenido
            print(content, end="", flush=True)
            time.sleep(0.02)  # Pausa ligeramente más larga para ver el análisis
        
        # Estadísticas finales
        print(f"\\n\\n=== ESTADÍSTICAS FINALES ===")
        print(f"Total de chunks: {chunk_count}")
        print(f"Palabras aproximadas: {words_processed}")
        print(f"Caracteres totales: {len(total_content)}")
        print(f"Promedio chars/chunk: {len(total_content)/chunk_count if chunk_count > 0 else 0:.1f}")
        
    except Exception as e:
        print(f"\\n✗ Error: {e}")

# Ejecutar streaming avanzado
streaming_avanzado()
# Out:
# === STREAMING AVANZADO CON ANÁLISIS ===
# Analizando chunks conforme llegan...
#
# **Inteligencia Artificial (IA\n[Progreso: 10 chunks, ~8 palabras]\n
# ):**
# La inteligencia artificial es una rama de\n[Progreso: 20 chunks, ~17 palabras]\n
#  la informática que busca crear sistemas capaces de realizar tareas\n[Progreso: 30 chunks, ~27 palabras]\n
#  que normalmente requieren inteligencia humana. Estas tareas incluyen entender\n[Progreso: 40 chunks, ~37 palabras]\n
#  el lenguaje, reconocer imágenes, tomar decisiones, resolver\n[Progreso: 50 chunks, ~47 palabras]\n
#  problemas, entre otras. La IA se basa en\n[Progreso: 60 chunks, ~57 palabras]\n
#  algoritmos y modelos matemáticos que permiten a las\n[Progreso: 70 chunks, ~67 palabras]\n
#  máquinas simular procesos cognitivos humanos.
#
# **¿\n[Progreso: 80 chunks, ~77 palabras]\n
# Cómo funciona el Machine Learning?**
# El **\n[Progreso: 90 chunks, ~86 palabras]\n
# machine learning** (aprendizaje automático) es\n[Progreso: 100 chunks, ~96 palabras]\n
#  una subdisciplina dentro de la IA. Cons\n[Progreso: 110 chunks, ~106 palabras]\n
# iste en programas que pueden “aprender” a\n[Progreso: 120 chunks, ~116 palabras]\n
#  realizar tareas a partir de datos, sin ser explíc\n[Progreso: 130 chunks, ~126 palabras]\n
# itamente programados para cada caso. El proceso básico\n[Progreso: 140 chunks, ~136 palabras]\n
#  es:
#
# 1. **Entrenamiento:**
# \n[Progreso: 150 chunks, ~144 palabras]\n
#    Se alimenta al algoritmo con muchos ejemplos de\n[Progreso: 160 chunks, ~154 palabras]\n
#  datos (por ejemplo, imágenes de gatos y perros\n[Progreso: 170 chunks, ~164 palabras]\n
# ), junto con la respuesta correcta (las etiquetas:\n[Progreso: 180 chunks, ~174 palabras]\n
#  “gato” o “perro”).
#
# 2\n[Progreso: 190 chunks, ~184 palabras]\n
# . **Modelo:**
#    El algoritmo analiza los\n[Progreso: 200 chunks, ~192 palabras]\n
#  datos y encuentra patrones o reglas que le permiten distinguir\n[Progreso: 210 chunks, ~202 palabras]\n
#  entre las diferentes clases.
#
# 3. **Predicción\n[Progreso: 220 chunks, ~212 palabras]\n
# :**
#    Una vez entrenado, el modelo\n[Progreso: 230 chunks, ~220 palabras]\n
#  puede recibir nuevos datos (una imagen no vista antes\n[Progreso: 240 chunks, ~230 palabras]\n
# ) y tratar de predecir la respuesta correcta\n[Progreso: 250 chunks, ~240 palabras]\n
#  (por ejemplo, si la imagen es de un\n[Progreso: 260 chunks, ~250 palabras]\n
#  gato o un perro).
#
# 4. **Mej\n[Progreso: 270 chunks, ~260 palabras]\n
# ora:**
#    Si el modelo comete errores\n[Progreso: 280 chunks, ~268 palabras]\n
# , se puede ajustar (con más datos o modific\n[Progreso: 290 chunks, ~278 palabras]\n
# ando los algoritmos) para mejorar su precisión.
#
# \n[Progreso: 300 chunks, ~288 palabras]\n
# En resumen, la IA busca que las máquinas “\n[Progreso: 310 chunks, ~298 palabras]\n
# piensen” y el machine learning les permite “\n[Progreso: 320 chunks, ~308 palabras]\n
# aprender” mediante la experiencia, haciendo que mejor\n[Progreso: 330 chunks, ~318 palabras]\n
# en su desempeño con el tiempo y el uso de\n[Progreso: 340 chunks, ~328 palabras]\n
#  datos.\n\n=== ESTADÍSTICAS FINALES ===
# Total de chunks: 343
# Palabras aproximadas: 329
# Caracteres totales: 1569
# Promedio chars/chunk: 4.6

# %% [markdown]
# ## Consideraciones Técnicas del Streaming
#
# ### Cuándo Usar Streaming:
# ✅ **SÍ usar streaming:**
# - Respuestas largas (>100 tokens)
# - Aplicaciones interactivas
# - Chatbots y asistentes
# - Demostraciones en vivo
# - Cuando la UX es prioritaria
#
# ❌ **NO usar streaming:**
# - Respuestas muy cortas
# - Procesamiento batch
# - APIs de backend sin interfaz
# - Cuando necesitas la respuesta completa antes de procesar
#
# ### Mejores Prácticas:
# 1. **Manejo de errores**: Siempre incluye try/catch
# 2. **Indicadores visuales**: Muestra progreso al usuario
# 3. **Cancelación**: Permite al usuario interrumpir
# 4. **Buffer management**: Para interfaces web, considera buffering
# 5. **Performance**: Monitorea el uso de recursos
#
# ## Ejercicios Prácticos
#
# ### Ejercicio 1: Indicador de Progreso
# Modifica el código para mostrar un indicador de progreso (spinner, barra, porcentaje).
#
# ### Ejercicio 2: Streaming con Filtros
# Implementa streaming que filtre o procese chunks específicos (ej: resaltar palabras clave).
#
# ### Ejercicio 3: Chatbot Mejorado
# Extiende el chatbot con:
# - Historial de conversación
# - Comandos especiales (/help, /clear)
# - Diferentes personalidades
#
# ## Conceptos Clave Aprendidos
#
# 1. **Streaming** mejora la percepción de velocidad
# 2. **Chunks** se procesan individualmente en tiempo real
# 3. **UX** es significativamente mejor con streaming
# 4. **Implementación** requiere manejo cuidadoso de generadores
# 5. **Casos de uso** específicos donde streaming aporta valor
#
# ## Próximos Pasos
#
# En el siguiente notebook exploraremos la **memoria en LangChain**, que nos permite mantener contexto entre múltiples interacciones del usuario.
